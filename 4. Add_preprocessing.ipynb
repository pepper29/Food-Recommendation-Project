# %%
# 형태소 분석 전에 Q,A,label로 만들어두기

# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/ADMIN/Documents/수업파일/221228(Final)/전처리단계/3.결측치,불용어제거/clean_total_crawling.csv', index_col = 0)
data.head()
# Out:
#                                              reviews  label
# 0  호반_한식주점부문 맛집 2   최초방문_ 21년 12월 최근방문_ 22년 11월  ...      1
# 1  이번엔 도가니무침을 먹어보았는데 크기도 크고 양도 많았다  맛도 딱 소주안주로 좋았...      1
# 2                                         병어찜 순대 낙원동      1
# 3        여전히 종로3가에서 최고의 맛집은 호반이다  우설수육은 정말 최고 미쳤다         1
# 4  애정하는 종로  호반 의 우거지국  식사 메뉴이다 고기를 삶아내니 육수가 기본적으로...      1

# %%
data['A'] = ' '

# %%
data
# Out:
#                                                 reviews  label  A
# 0     호반_한식주점부문 맛집 2   최초방문_ 21년 12월 최근방문_ 22년 11월  ...      1
# 1     이번엔 도가니무침을 먹어보았는데 크기도 크고 양도 많았다  맛도 딱 소주안주로 좋았...      1
# 2                                            병어찜 순대 낙원동      1
# 3           여전히 종로3가에서 최고의 맛집은 호반이다  우설수육은 정말 최고 미쳤다         1
# 4     애정하는 종로  호반 의 우거지국  식사 메뉴이다 고기를 삶아내니 육수가 기본적으로...      1
# ...                                                 ...    ... ..
# 3840                                   쌀국수는 평범 덮밥은 괜찮아요      9
# 3841   을지로  베트남 분짜 정말 맛있었어요  사실 고추뼈찜을 먹으러 간건데 점심 때는 ...      9
# 3842  입국 금지임에도 갈 수 있는 베트남이 이...      9
# 3843  덮밥에 함께 나오는 고기는 약간 매웠어요 그치만 적당히 잘구워져서 맛있었고  밥에 ...      9
# 3844  베트남쌀국수가 너무 먹고싶어서 들린 을지깐깐 분위기는 힙지로답게 조명부터 해서 너무...      9
#
# [72827 rows x 3 columns]

# %%
data = data.reindex(columns=["reviews", "A", "label"])

# %%
data
# Out:
#                                                 reviews  A  label
# 0     호반_한식주점부문 맛집 2   최초방문_ 21년 12월 최근방문_ 22년 11월  ...         1
# 1     이번엔 도가니무침을 먹어보았는데 크기도 크고 양도 많았다  맛도 딱 소주안주로 좋았...         1
# 2                                            병어찜 순대 낙원동         1
# 3           여전히 종로3가에서 최고의 맛집은 호반이다  우설수육은 정말 최고 미쳤다            1
# 4     애정하는 종로  호반 의 우거지국  식사 메뉴이다 고기를 삶아내니 육수가 기본적으로...         1
# ...                                                 ... ..    ...
# 3840                                   쌀국수는 평범 덮밥은 괜찮아요         9
# 3841   을지로  베트남 분짜 정말 맛있었어요  사실 고추뼈찜을 먹으러 간건데 점심 때는 ...         9
# 3842  입국 금지임에도 갈 수 있는 베트남이 이...         9
# 3843  덮밥에 함께 나오는 고기는 약간 매웠어요 그치만 적당히 잘구워져서 맛있었고  밥에 ...         9
# 3844  베트남쌀국수가 너무 먹고싶어서 들린 을지깐깐 분위기는 힙지로답게 조명부터 해서 너무...         9
#
# [72827 rows x 3 columns]

# %%
intent_word = ['', '한정식', '해장국', '해산물', '칼국수', '간장게장',
               '냉면', '전골', '곱창', '국수', '떡볶이',
               '김밥', '순대', '샌드위치', '버거', '타코',
               '쌀국수', '월남쌈', '케이크', '아이스크림', '마카롱',
               '스시', '라멘', '생선회', '돈카츠', '베이커리',
               '통닭', '파스타', '피자', '중식', '마라탕']

# %%
data[data['label'] == 1]
# Out:
#                                                 reviews  A  label
# 0     호반_한식주점부문 맛집 2   최초방문_ 21년 12월 최근방문_ 22년 11월  ...         1
# 1     이번엔 도가니무침을 먹어보았는데 크기도 크고 양도 많았다  맛도 딱 소주안주로 좋았...         1
# 2                                            병어찜 순대 낙원동         1
# 3           여전히 종로3가에서 최고의 맛집은 호반이다  우설수육은 정말 최고 미쳤다            1
# 4     애정하는 종로  호반 의 우거지국  식사 메뉴이다 고기를 삶아내니 육수가 기본적으로...         1
# ...                                                 ... ..    ...
# 2443  제주향토음식 명인이 운영하신다는 낭푼밥상에 갔다  제주도를 여러번 다녀오면서 몸국은...         1
# 2444  종로구에서 직접 매일 만드는 두부집인 미당순두부 다녀왔어요  가고자 했던 곳이 재건...         1
# 2445  토속순두부 처음 먹고 한달 후에 비지찌개 또 먹으러 감  가격은 대부분 9천원  수...         1
# 2446  제육순두부 먹기 싫어서 토속순두부 시켰는데 그냥 순두부를 물에 넣고 끓인게 나왔어요...         1
# 2447  두번 방문했는데 두번 다 대만족이요 하얀 순두부랑 비지찌개 먹어봤어요 비지찌개 핵맛...         1
#
# [2440 rows x 3 columns]

# %%
data.loc[data['label'] == 1, 'A'] = '한정식' #바꾸는 식

# %%
for i in range(1, 31):
    data.loc[data['label']==i, 'A'] = intent_word[i] #바꾸는 반복문 작성

# %%
data[data['label'] == 3] #랜덤번호로 데이터확인 1~30까지 전체확인완료
# Out:
#                                                 reviews    A  label
# 0     오징어회 매우 맛있음 다른 메뉴도 맛있음  가격은 싸진 않음 분위기는 포차 분위기 ...  해산물      3
# 1     요약  오징어는 꼬득한게 아니라 쫄깃하구나 몰랐던 맛 찾아주는 소주집  무려 4차로...  해산물      3
# 2           평점 너무 높은듯 ㅋㅋㅋㅋㅋㅋㅋ 그냥저냥 소주먹기 좋다 젊은친구들 오기 좋은곳  해산물      3
# 3     드디어 재방문  거의 3년만    감탄해서 한 번 더 주문했던 포뜬 오징어회를 못 ...  해산물      3
# 4       친절하신 사장님과 맛있는 오징어회   언제가도 웨이팅 극악인 이곳은 한번 날을 ...  해산물      3
# ...                                                 ...  ...    ...
# 2886  4명이서 부족할 줄 알았는데 배부르게 잘 먹었습니다  회  고기  생선  튀김 등 ...  해산물      3
# 2887                                          맛있고 비쌈     해산물      3
# 2888  음식은 둘째이고 서비스 때문에 다시는 갈 일이 없네요  1 들어갔을때 멀뚱멀뚱 쳐다...  해산물      3
# 2889  분위기 좋은 생선조림집  제주식당  한남동의 괜찮은 회 생선구이 생선조림집이다  분...  해산물      3
# 2890  갈치조림이랑 육전 먹었는데  갈치조림이 너무 달았어요 전반적으로 음식 간이 달더라구...  해산물      3
#
# [2879 rows x 3 columns]

# %%
for i in range(1, 30): #리스트 데이터확인
    intent_word[i]
print(intent_word)
# Out:
# ['', '한정식', '해장국', '해산물', '칼국수', '간장게장', '냉면', '전골', '곱창', '국수', '떡볶이', '김밥', '순대', '샌드위치', '버거', '타코', '쌀국수', '월남쌈', '케이크', '아이스크림', '마카롱', '스시', '라멘', '생선회', '돈카츠', '베이커리', '통닭', '파스타', '피자', '중식', '마라탕']

# %%
data
# Out:
#                                                 reviews    A  label
# 0     호반_한식주점부문 맛집 2   최초방문_ 21년 12월 최근방문_ 22년 11월  ...  한정식      1
# 1     이번엔 도가니무침을 먹어보았는데 크기도 크고 양도 많았다  맛도 딱 소주안주로 좋았...  한정식      1
# 2                                            병어찜 순대 낙원동  한정식      1
# 3           여전히 종로3가에서 최고의 맛집은 호반이다  우설수육은 정말 최고 미쳤다     한정식      1
# 4     애정하는 종로  호반 의 우거지국  식사 메뉴이다 고기를 삶아내니 육수가 기본적으로...  한정식      1
# ...                                                 ...  ...    ...
# 3840                                   쌀국수는 평범 덮밥은 괜찮아요   국수      9
# 3841   을지로  베트남 분짜 정말 맛있었어요  사실 고추뼈찜을 먹으러 간건데 점심 때는 ...   국수      9
# 3842  입국 금지임에도 갈 수 있는 베트남이 이...   국수      9
# 3843  덮밥에 함께 나오는 고기는 약간 매웠어요 그치만 적당히 잘구워져서 맛있었고  밥에 ...   국수      9
# 3844  베트남쌀국수가 너무 먹고싶어서 들린 을지깐깐 분위기는 힙지로답게 조명부터 해서 너무...   국수      9
#
# [72827 rows x 3 columns]

# %%
# cleasing 함수 
import re
def cleasing(text):
    repl =''
    pattern = '([ㄱ-ㅎㅏ-ㅣ]+)' # 자음, 모음 제거
    text = re.sub(pattern= pattern, repl=repl, string=text)
    #pattern = '[^\w\s]' # 특수기호 제거
    pattern = '[^가-히\s]' # 특수기호 제거
    text = re.sub(pattern= pattern, repl=repl, string=text)
    return text

# %%
import copy
data2 = copy.deepcopy(data)
data2
# Out:
#                                                 reviews    A  label
# 0     호반_한식주점부문 맛집 2   최초방문_ 21년 12월 최근방문_ 22년 11월  ...  한정식      1
# 1     이번엔 도가니무침을 먹어보았는데 크기도 크고 양도 많았다  맛도 딱 소주안주로 좋았...  한정식      1
# 2                                            병어찜 순대 낙원동  한정식      1
# 3           여전히 종로3가에서 최고의 맛집은 호반이다  우설수육은 정말 최고 미쳤다     한정식      1
# 4     애정하는 종로  호반 의 우거지국  식사 메뉴이다 고기를 삶아내니 육수가 기본적으로...  한정식      1
# ...                                                 ...  ...    ...
# 3840                                   쌀국수는 평범 덮밥은 괜찮아요   국수      9
# 3841   을지로  베트남 분짜 정말 맛있었어요  사실 고추뼈찜을 먹으러 간건데 점심 때는 ...   국수      9
# 3842  입국 금지임에도 갈 수 있는 베트남이 이...   국수      9
# 3843  덮밥에 함께 나오는 고기는 약간 매웠어요 그치만 적당히 잘구워져서 맛있었고  밥에 ...   국수      9
# 3844  베트남쌀국수가 너무 먹고싶어서 들린 을지깐깐 분위기는 힙지로답게 조명부터 해서 너무...   국수      9
#
# [72827 rows x 3 columns]

# %%
data['reviews'] = data['reviews'].map(lambda x: cleasing(x))

# %%
data['reviews'].replace(' ', '')
# Out:
# 0       호반한식주점부문 맛집    최초방문 년 월 최근방문 년 월    첫 방문 이후 꽤 ...
# 1       이번엔 도가니무침을 먹어보았는데 크기도 크고 양도 많았다  맛도 딱 소주안주로 좋았...
# 2                                              병어찜 순대 낙원동
# 3              여전히 종로가에서 최고의 맛집은 호반이다  우설수육은 정말 최고 미쳤다
# 4       애정하는 종로  호반 의 우거지국  식사 메뉴이다 고기를 삶아내니 육수가 기본적으로...
#                               ...
# 3840                                     쌀국수는 평범 덮밥은 괜찮아요
# 3841     을지로  베트남 분짜 정말 맛있었어요  사실 고추뼈찜을 먹으러 간건데 점심 때는 ...
# 3842                                                  ...
# 3843    덮밥에 함께 나오는 고기는 약간 매웠어요 그치만 적당히 잘구워져서 맛있었고  밥에 ...
# 3844    베트남쌀국수가 너무 먹고싶어서 들린 을지깐깐 분위기는 지로답게 조명부터 해서 너무 ...
# Name: reviews, Length: 72827, dtype: object

# %%
data
# Out:
#                                                 reviews    A  label
# 0     호반한식주점부문 맛집    최초방문 년 월 최근방문 년 월    첫 방문 이후 꽤 ...  한정식      1
# 1     이번엔 도가니무침을 먹어보았는데 크기도 크고 양도 많았다  맛도 딱 소주안주로 좋았...  한정식      1
# 2                                            병어찜 순대 낙원동  한정식      1
# 3            여전히 종로가에서 최고의 맛집은 호반이다  우설수육은 정말 최고 미쳤다     한정식      1
# 4     애정하는 종로  호반 의 우거지국  식사 메뉴이다 고기를 삶아내니 육수가 기본적으로...  한정식      1
# ...                                                 ...  ...    ...
# 3840                                   쌀국수는 평범 덮밥은 괜찮아요   국수      9
# 3841   을지로  베트남 분짜 정말 맛있었어요  사실 고추뼈찜을 먹으러 간건데 점심 때는 ...   국수      9
# 3842                                                ...   국수      9
# 3843  덮밥에 함께 나오는 고기는 약간 매웠어요 그치만 적당히 잘구워져서 맛있었고  밥에 ...   국수      9
# 3844  베트남쌀국수가 너무 먹고싶어서 들린 을지깐깐 분위기는 지로답게 조명부터 해서 너무 ...   국수      9
#
# [72827 rows x 3 columns]

# %%
data[data['label'] == 11]
# Out:
#                                                 reviews   A  label
# 0                                                        김밥     11
# 1     세상 모든 걸 튀겨버릴 것만 같은 튀김집  국물맛이 좋았던 쌀떡볶이는 튀김의 느낌을...  김밥     11
# 2     원래 백종원 골목식당나온 떡볶이집 가려고 했는데 재료 소진     온게 아쉬워서 바...  김밥     11
# 3      원에 맛보는 궁극의 분식튀김 코스요리     신림동 고시촌을 비추는 두 개의 빛 ...  김밥     11
# 4        튀김으로 고평가된 느낌  떡볶이는 별로     튀김으로 유명한 집이죠  튀김이...  김밥     11
# ...                                                 ...  ..    ...
# 1307  제 닉넴 석자 떡볶이를 걸고   이 곳은 꽤나 맛집임을 인정   찾아갈 정도는 아니...  김밥     11
# 1308  선향원에서 소고기덮밥을 먹고 나와 기왕 이쪽 동네에 온 길에 또 다른 들를만한 가게...  김밥     11
# 1309  골목떡볶이와 멀어지고나서 동네에 갈만한 떡볶이 집이 없었는데 발견한 보물같은 집  ...  김밥     11
# 1310  여기 국물떡볶이인데 진짜 맛있다    완전 동네 분식집인데  이렇게 맛있을 일   ...  김밥     11
# 1311                              괜찮은편  튀김은 진짜 바삭하고 맛있음  김밥     11
#
# [1310 rows x 3 columns]

# %%
data
# Out:
#                                                 reviews    A  label
# 0     호반한식주점부문 맛집    최초방문 년 월 최근방문 년 월    첫 방문 이후 꽤 ...  한정식      1
# 1     이번엔 도가니무침을 먹어보았는데 크기도 크고 양도 많았다  맛도 딱 소주안주로 좋았...  한정식      1
# 2                                            병어찜 순대 낙원동  한정식      1
# 3            여전히 종로가에서 최고의 맛집은 호반이다  우설수육은 정말 최고 미쳤다     한정식      1
# 4     애정하는 종로  호반 의 우거지국  식사 메뉴이다 고기를 삶아내니 육수가 기본적으로...  한정식      1
# ...                                                 ...  ...    ...
# 3840                                   쌀국수는 평범 덮밥은 괜찮아요   국수      9
# 3841   을지로  베트남 분짜 정말 맛있었어요  사실 고추뼈찜을 먹으러 간건데 점심 때는 ...   국수      9
# 3842                                                ...   국수      9
# 3843  덮밥에 함께 나오는 고기는 약간 매웠어요 그치만 적당히 잘구워져서 맛있었고  밥에 ...   국수      9
# 3844  베트남쌀국수가 너무 먹고싶어서 들린 을지깐깐 분위기는 지로답게 조명부터 해서 너무 ...   국수      9
#
# [72827 rows x 3 columns]

# %%
print(data.isnull().sum())
# Out:
# reviews    0
# A          0
# label      0
# dtype: int64

# %%
data.to_csv('refine_total_data5.csv', header=True, index=False)
